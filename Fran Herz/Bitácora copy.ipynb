# %% [markdown]
# # Bitácora — Franck–Hertz (Hg)
# **Universidad de los Andes — Laboratorio Intermedio**
# **Fecha:** 2025-09-16 19:36
# **Estudiantes:** Ángela Bustos , Mariana Montoya.
# **Correos:** av.bustos@uniandes.edu.co ,
#
# **Sitio de guardado:** https://github.com/ValentinaBustos2025/Lab-Intermedio.git (en la nube).
#
# **Carpeta :** Fran Herz
#
# **Archivo:** Bitácora.ipynb
#
# <p align="center">
#   <img src="guardado.jpg" alt="Mi imagen" width="600">
# </p>
#
# **Subcarpetas con nombres asignados:** Data
#
# <p align="center">
#   <img src="guardado1.jpg" alt="Mi imagen" width="600">
# </p>

# %% [markdown]
# ---
# ## Objetivos
# - Medir la cuantización de la energía de estados electrónicos en átomos de Mercurio (Hg).
# - Entender cómo la temperatura afecta la densidad del gas y el camino libre medio.
# - Calcular la energía entre el estado base y el primer estado excitado del Hg.

# %% [markdown]
# ---
# ## Marco Teórico
#
# En 1914, James Franck y Gustav Hertz demostraron experimentalmente la **cuantización de la energía** en átomos de mercurio (Hg), validando la idea central de la teoría de **Bohr** (1913): los electrones en los átomos ocupan **niveles discretos** de energía y las transiciones entre ellos implican ganancias o pérdidas de paquetes de energía bien definidos.
#
# ### 1) Fundamentos de Bohr (contexto)
# - Los electrones se mueven en **órbitas estacionarias** con energías cuantizadas.
# - La emisión/absorción de radiación ocurre cuando el electrón **salta** entre niveles con diferencia de energía **ΔE = hν**.
# - Aunque Bohr formuló su modelo para el hidrógeno, el hallazgo de Franck–Hertz mostró que la **cuantización** también se manifiesta en átomos multielectrónicos (como Hg) mediante impactos electrónicos.
#
# ### 2) Colisiones electrón–átomo en Hg
# - **Elásticas:** el electrón cambia de dirección, pero la **energía cinética** total se conserva (la pérdida es despreciable debido a que $m_e \ll M_{\mathrm{Hg}}$).
#
# - **Inelásticas:** si la energía del electrón supera el umbral de excitación $E_a$, transfiere aproximadamente \(E_a\) al átomo (p. ej., 4.67 eV para el primer estado excitado relevante de Hg), dejando menos energía cinética remanente.
#
# Como consecuencia, al **aumentar** el voltaje acelerador $U_1$, la corriente medida $I_A$ exhibe **mínimos periódicos**: en cada umbral, muchos electrones sufren colisiones inelásticas y **no** alcanzan el ánodo (o no superan $U_2$), produciendo una caída en $I_A$.
#
# ### 3) Rol de la temperatura y el camino libre medio
# La **densidad** de átomos de Hg en el tubo depende de la **presión de vapor** y la **temperatura**. Modelando el Hg como gas ideal, $n = P/(k_B T)$. El **camino libre medio**,
# \[
# \bar{\ell} = \frac{1}{\sqrt{2}\,n\,\sigma},
# \]
# representa la distancia promedio entre colisiones electrón–átomo (con $\sigma \approx \pi r^2$ una sección eficaz efectiva).
# - Si $\bar{\ell} \ll L$ (siendo $L$ la distancia cátodo–ánodo), **se incrementa** la probabilidad de múltiples colisiones dentro del tubo y aparecen **varios** mínimos/ máximos en $I_A(U_1)$.
# - Si $\bar{\ell}$ es **comparable** a $L$, disminuye el número de colisiones y se **suprime** la estructura de picos.
#
# ### 4) Voltaje de retardo $U_2$ y emisión termoiónica $U_H$
# - **\(U_2\)** (retardo) establece un umbral de energía: solo los electrones con energía cinética suficiente lo superan y contribuyen a \(I_A\). Al **aumentar** \(U_2\), se filtran más electrones de baja energía, lo que **desplaza** o **acentúa** los mínimos.
# - **\(U_H\)** (calentamiento del cátodo) controla la **emisión termoiónica** y la distribución de energías iniciales de los electrones (tipo Maxwell–Boltzmann). Cambios en \(U_H\) afectan la **amplitud** de \(I_A\), el **ancho** de valles/picos y la reproducibilidad.
#
# ### 5) Distancias entre mínimos y estimación de $E_a$ y $\bar{\ell}$
# Denotando por $U_1^{(n)}$ la posición del **n-ésimo mínimo** de $I_A(U_1)$, la **separación** entre mínimos consecutivos $\Delta E(n) = U_1^{(n)} - U_1^{(n-1)}$ (en voltios ~ eV) crece débilmente con $n debido a que, con mayores $U_1$, el electrón gana energía adicional en cada tramo libre $\bar{\ell}$. Un modelo efectivo predice:
# \[
# \Delta E(n) \approx \left(1 + \frac{\bar{\ell}}{L}(2n-1)\right) E_a.
# \]
# - Ajustando $\Delta E(n)$ vs. $n$ se obtiene la **pendiente** que permite estimar $\bar{\ell}_{\mathrm{exp}}$.
# - Extrapolando a $n=1/2$, se estima $E_a \approx \Delta E(0.5)$, que se compara con el valor tabulado de Hg (~4.67 eV).
#
# **Conclusión teórica:** la aparición de mínimos periódicos en $I_A(U_1)$ y su **separación característica** constituyen una verificación directa de la **cuantización** de los niveles atómicos. La sensibilidad de la curva a $T$, $U_2$ y $U_H$ habilita, además, la **caracterización** del medio (densidad/camino libre) y del proceso de emisión.
#
#
# ---
#
# ## Montaje Experimental
# - Tubo de Franck-Hertz en estufa.
# - Módulo de control y medición (conexiones: UH, U1, U2).
# - Osciloscopio para modo XY.
# - Software *Phywe Measure 4* para adquisición de datos.
#
# Precauciones:
# - T < 190 °C.
# - U1 < 60 V, UH < 7 V, U2 < 3 V.
#
#
# <p align="center">
#   <img src="montaje.jpg" alt="Montaje 1" width="400">
#   <img src="montaje2.png" alt="Montaje 2" width="600">
# </p>
#
# Esquema del tubo de Franck–Hertz con vapor de mercurio. Los electrones son emitidos desde el cátodo calentado por el voltaje $U_H$ y posteriormente acelerados por el potencial $U_B$. Durante su recorrido, los electrones pueden colisionar de manera inelástica con los átomos de mercurio, transfiriendo una energía discreta de excitación. Finalmente, el voltaje de frenado $U_A$ asegura que solo los electrones con suficiente energía cinética lleguen al ánodo, donde la corriente es medida por el amperímetro $A$.

# %%
##LIBRERIAS ###
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.signal import find_peaks
from matplotlib.ticker import AutoMinorLocator
from IPython.display import display
from pathlib import Path
from scipy.constants import e

# %%
##CARGA DE DATOS## 
def leer_columnas(path_archivo):
    columnas = []

    with open(Path(path_archivo), "r", encoding="latin-1", errors="ignore") as f:
        for linea in f:
            partes = linea.strip().replace(",", ".").split()
            
            next(f)
            try:
                fila = [float(x) for x in partes]
                
                if not columnas:
                    columnas = [[] for _ in range(len(fila))]
           
                for i, val in enumerate(fila):
                    columnas[i].append(val)
            except ValueError:
                
                continue

    return np.array(columnas)

# %%
# Skip the first line of a file and read the rest
with open('your_file.txt', 'r', encoding='utf-8') as f:
    next(f)  # Skip the first line
    for line in f:
        # Process each subsequent line
        print(line.strip())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Skip the first line of a file and read the rest
# ----> 2 with open('your_file.txt', 'r', encoding='utf-8') as f:
#       3     next(f)  # Skip the first line
#       4     for line in f:
#       5         # Process each subsequent line
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# ...

# %% [markdown]
# ---
#
# ## Actividad 2
#
# 1. Tome varias series de datos con la misma temperatura, procure que las variaciones en esta sean m´ınimas. ¿C´omo se comparan las diferentes gr´aficas? ¿C´omo afectan estas peque˜nas fluctuaciones en la temperatura a sus resultados? ¿Se justifica un an´alisis estad´ıstico?

# %% [markdown]
# Las diferentes series de datos tomadas a la misma temperatura muestran un comportamiento muy similar: los picos y mínimos de corriente se alinean bastante bien entre sí, aunque hay pequeñas diferencias en la altura de los picos y en la posición exacta de los mínimos. Estas pequeñas fluctuaciones se deben a ligeras variaciones en la temperatura, que afectan la energía media de los electrones y, por lo tanto, la corriente medida en los máximos y mínimos. Aunque los efectos son sutiles, se observan desplazamientos menores en la posición de los mínimos de voltaje.

# %%
## GRÁFICAS PARA 175° ###
carpeta = Path("Data/Act1/175°")
v_col, i_col = 0, 1                      # índices: voltaje y corriente en lo que devuelva leer_columnas()
LABEL_Y = "Corriente (nA)"               # cambia si tu unidad no es nA

# Estructura para reutilizar en celdas siguientes
resultados1 = {}
color_n1 = "#D6259B"   # rosa fuerte
color_n2 = "#51D63F"   # verde
color_n3 = "#2580D6"   # azul
colores = [color_n1, color_n2, color_n3]

fig, ax = plt.subplots(figsize=(18, 9))

for i, archivo in enumerate(sorted(carpeta.glob("*.txt"))):
    cols = leer_columnas(archivo)        # <-- TU función de carga
    if cols is None:
        continue
    cols = np.asarray(cols)
    if cols.ndim != 2 or cols.shape[0] <= max(v_col, i_col):
        continue

    V = np.asarray(cols[v_col], dtype=float)
    I = np.asarray(cols[i_col], dtype=float)

    # limpieza
    m = np.isfinite(V) & np.isfinite(I)
    V, I = V[m], I[m]
    if V.size == 0: 
        continue

    # parámetros adaptativos de picos
    rango = np.ptp(I)
    prominence = max(0.1, 0.05 * rango)
    distance   = max(5, len(I)//50)

    idx_max, _ = find_peaks(I,  distance=distance, prominence=prominence)
    idx_min, _ = find_peaks(-I, distance=distance, prominence=prominence)

    resultados1[archivo.stem] = {
        "V": V, "I": I,
        "idx_max": idx_max, "idx_min": idx_min
    }

    color = colores[i % len(colores)]
    ax.plot(V, I, marker="o", markersize=3, color=color, linewidth=0.9, label=archivo.stem)


    if idx_max.size:
        ax.plot(V[idx_max], I[idx_max], "x", color="black", markersize=6)
    if idx_min.size:
        ax.plot(V[idx_min], I[idx_min], "v", color="black", markersize=6)


ax.set_xlabel("Voltaje U1 (V)", fontsize=40, labelpad=12)
ax.set_ylabel(LABEL_Y, fontsize=40, labelpad=12)
ax.set_title("Diferentes tomas con la misma temperatura de 175°", fontsize=40, pad=14)
ax.tick_params(axis="both", labelsize=35)   # <<< aumenta el tamaño de los números en los ejes
ax.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## PROMEDIO GRÁFICA

# %%
## GRÁFICAS PARA 175° ###
carpeta = Path("Data/Act1/175°")
v_col, i_col = 0, 1                      # índices: voltaje y corriente en lo que devuelva leer_columnas()
LABEL_Y = "Corriente (nA)"               # cambia si tu unidad no es nA

# Estructura para reutilizar en celdas siguientes
resultados1 = {}
color_n1 = "#D6259B"   # rosa fuerte
color_n2 = "#51D63F"   # verde
color_n3 = "#2580D6"   # azul
colores = [color_n1, color_n2, color_n3]

fig, ax = plt.subplots(figsize=(18, 9))

for i, archivo in enumerate(sorted(carpeta.glob("*.txt"))):
    cols = leer_columnas(archivo)        # <-- TU función de carga
    if cols is None:
        continue
    cols = np.asarray(cols)
    if cols.ndim != 2 or cols.shape[0] <= max(v_col, i_col):
        continue

    V = np.asarray(cols[v_col], dtype=float)
    I = np.asarray(cols[i_col], dtype=float)

    # limpieza
    m = np.isfinite(V) & np.isfinite(I)
    V, I = V[m], I[m]
    if V.size == 0: 
        continue

    # parámetros adaptativos de picos
    rango = np.ptp(I)
    prominence = max(0.1, 0.05 * rango)
    distance   = max(5, len(I)//50)

    idx_max, _ = find_peaks(I,  distance=distance, prominence=prominence)
    idx_min, _ = find_peaks(-I, distance=distance, prominence=prominence)

    resultados1[archivo.stem] = {
        "V": V, "I": I,
        "idx_max": idx_max, "idx_min": idx_min
    }

    color = colores[i % len(colores)]
    ax.plot(V, I, marker="o", markersize=3, color=color, linewidth=0.9, label=archivo.stem)


    if idx_max.size:
        ax.plot(V[idx_max], I[idx_max], "x", color="black", markersize=6)
    if idx_min.size:
        ax.plot(V[idx_min], I[idx_min], "v", color="black", markersize=6)

# --- Paso 1: guardar listas de V e I ---
all_V = [res["V"] for res in resultados1.values()]
all_I = [res["I"] for res in resultados1.values()]

# --- Paso 2: definir rango común ---
V_min = max(v.min() for v in all_V)   # límite inferior común
V_max = min(v.max() for v in all_V)   # límite superior común
V_common = np.linspace(V_min, V_max, 800)   # eje común

# --- Paso 3: interpolar ---
I_interp = []
for V, I in zip(all_V, all_I):
    f = interp1d(V, I, kind="linear", bounds_error=False, fill_value=np.nan)
    I_interp.append(f(V_common))

I_interp = np.vstack(I_interp)   # matriz (#curvas x #puntos)

# --- Paso 4: promedio ignorando NaNs ---
I_mean = np.nanmean(I_interp, axis=0)

# --- Paso 5: graficar ---
fig, ax = plt.subplots(figsize=(18, 9))

# curvas originales en gris claro
for V, I in zip(all_V, all_I):
    ax.plot(V, I, color="gray", alpha=0.3)

# curva promedio destacada
ax.plot(V_common, I_mean, color="red", linewidth=2.5, label="Promedio")

ax.set_xlabel("Voltaje U1 (V)", fontsize=40, labelpad=12)
ax.set_ylabel(LABEL_Y, fontsize=40, labelpad=12)
ax.set_title("Promedio de las gráficas a 175°", fontsize=40, pad=14)
ax.tick_params(axis="both", labelsize=35)
ax.grid(True)
ax.legend(fontsize=25)
plt.tight_layout()
plt.show()

ax.set_xlabel("Voltaje U1 (V)", fontsize=40, labelpad=12)
ax.set_ylabel(LABEL_Y, fontsize=40, labelpad=12)
ax.set_title("Diferentes tomas con la misma temperatura de 175°", fontsize=40, pad=14)
ax.tick_params(axis="both", labelsize=35)   # <<< aumenta el tamaño de los números en los ejes
ax.grid(True)
plt.tight_layout()
plt.show()

# %%
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt

# --- Paso 1: guardar listas de V e I ---
all_V = [res["V"] for res in resultados1.values()]
all_I = [res["I"] for res in resultados1.values()]

# --- Paso 2: definir rango común ---
V_min = max(v.min() for v in all_V)
V_max = min(v.max() for v in all_V)
V_common = np.linspace(V_min, V_max, 800)

# --- Paso 3: interpolar ---
I_interp = []
for V, I in zip(all_V, all_I):
    f = interp1d(V, I, kind="linear", bounds_error=False, fill_value=np.nan)
    I_interp.append(f(V_common))

I_interp = np.vstack(I_interp)   # matriz (#curvas x #puntos)

# --- Paso 4: promedio y desviación estándar ---
I_mean = np.nanmean(I_interp, axis=0)
I_std  = np.nanstd(I_interp, axis=0)

# --- Paso 5: graficar ---
fig, ax = plt.subplots(figsize=(18, 9))

# curvas originales en gris claro
for V, I in zip(all_V, all_I):
    ax.plot(V, I, color="gray", alpha=0.3)

# curva promedio con barras de error
ax.errorbar(V_common, I_mean, yerr=I_std, 
            color="red", linewidth=2.5, 
            ecolor="black", elinewidth=1, capsize=3, 
            label="Promedio ± σ")

ax.set_xlabel("Voltaje U1 (V)", fontsize=40, labelpad=12)
ax.set_ylabel(LABEL_Y, fontsize=40, labelpad=12)
ax.set_title("Promedio de las gráficas a 175° con barras de error", fontsize=40, pad=14)
ax.tick_params(axis="both", labelsize=35)
ax.grid(True)
ax.legend(fontsize=25)
plt.tight_layout()
plt.show()

# %%
#TABLA DE REGISTRO Y VARIACIÓN

Ea_ref_eV = 4.67   # eV
filas = []
resumen = []

for name, d in resultados1.items():
    V, I, idx_min = d["V"], d["I"], d["idx_min"]
    if idx_min.size < 2:
        continue

    # tabla detallada por archivo
    Vmins = V[idx_min]
    Imins = I[idx_min]
    dV = np.diff(Vmins)                      # separación entre mínimos consecutivos
    Ea_est = dV                              # (en eV ~ ΔV cuando la corrección es pequeña)
    err_abs = np.abs(Ea_est - Ea_ref_eV)
    err_rel = 100 * err_abs / Ea_ref_eV


    # resumen por archivo (promedio)
    resumen.append({
        "archivo": name,
        "n_deltas": len(dV),
        "ΔV̄ (V)": np.mean(dV),
        "σ_ΔV (V)": np.std(dV, ddof=1) if len(dV) > 1 else np.nan,
        "E_a,est,mean (eV)": np.mean(Ea_est),
        "error_abs_mean (eV)": np.abs(np.mean(Ea_est) - Ea_ref_eV),
        "error_rel_mean (%)": 100*np.abs(np.mean(Ea_est) - Ea_ref_eV)/Ea_ref_eV
    })

#df_detalle = pd.DataFrame(filas)
df_resumen = pd.DataFrame(resumen).sort_values("archivo")

#print("► Tabla de mínimos consecutivos y estimación por ΔV (detalle):")
#display(df_detalle)

print("\n► Resumen por archivo (promedio y dispersión) para una temperatura de 175°:")
display(df_resumen)
# Out:
# ► Resumen por archivo (promedio y dispersión) para una temperatura de 175°:
#                                        archivo  n_deltas   ΔV̄ (V)  σ_ΔV (V)  \
# 0  20250918_Franck-Hertz_Actividad1_Toma1(175)         5  4.996000  0.098133
# 1  20250918_Franck-Hertz_Actividad1_Toma2(175)         4  4.982500  0.105317
# 2  20250918_Franck-Hertz_Actividad1_Toma3(175)         6  5.001667  0.118054
#
#    E_a,est,mean (eV)  error_abs_mean (eV)  error_rel_mean (%)
# 0           4.996000             0.326000            6.980728
# 1           4.982500             0.312500            6.691649
# 2           5.001667             0.331667            7.102070

# %%
# Carpetas
carpeta = Path("Data/Act1/175°")

# Resultados
resultados = {}
todos_diffs = []
todos_num = []

for archivo_ajuste in sorted(carpeta.glob("*AjusteMinimosyMaximos*.txt")):
    datos = []
    with open(archivo_ajuste, "r", encoding="utf-8") as f:
        for line in f:
            if line.startswith("mínimo"):
                parts = line.strip().split()
                if len(parts) >= 3:
                    voltaje = float(parts[1].replace(",", "."))
                    datos.append(voltaje)

    if not datos:
        continue

    diferencias = np.diff(datos)
    num_min = np.arange(1, len(diferencias) + 1)

    resultados[archivo_ajuste.stem] = (num_min, diferencias)

    # Guardar en arrays globales
    todos_diffs.extend(diferencias)
    todos_num.extend(num_min)

# Convertir a numpy arrays
todos_diffs = np.array(todos_diffs)
todos_num = np.array(todos_num)

# --- Ajuste lineal ---
coef = np.polyfit(todos_diffs, todos_num, 1)   # n = a*ΔV + b
a, b = coef
print(f"Ajuste lineal: n = {a:.3f} * ΔV + {b:.3f}")

# Puntos para la recta ajustada
x_fit = np.linspace(min(todos_diffs), max(todos_diffs), 200)
y_fit = a * x_fit + b

# --- Graficar ---
colores = ["#D6259B", "#51D63F", "#2580D6"]
fig, ax = plt.subplots(figsize=(12, 6))

for i, (nombre, (num_min, diffs)) in enumerate(resultados.items()):
    ax.scatter(diffs, num_min, color=colores[i % len(colores)], label=f"Toma {i+1}")

# Recta ajustada
ax.plot(x_fit, y_fit, "k--", linewidth=2, label=f"Ajuste: n = {a:.2f}·ΔV + {b:.2f}")
ax.set_title("Numero mínimo contra ΔV 175°", fontsize=40, pad=14)
ax.set_xlabel("ΔV entre mínimos (V)")
ax.set_ylabel("Número de mínimo")
ax.set_yticks(range(1, max(todos_num)+1))
ax.grid(True)
ax.legend(ncol=2, fontsize=9)
plt.show()
# Out:
# Ajuste lineal: n = 12.556 * ΔV + -58.298

# %%
## GRÁFICAS PARA 180° ###
carpeta = Path("Data/Act1/180°")
v_col, i_col = 0, 1                      # índices: voltaje y corriente en lo que devuelva leer_columnas()
LABEL_Y = "Corriente (nA)"               # cambia si tu unidad no es nA

# Estructura para reutilizar en celdas siguientes
resultados2 = {}
color_n1 = "#D6259B"   # rosa fuerte
color_n2 = "#51D63F"   # verde
color_n3 = "#2580D6"   # azul
colores = [color_n1, color_n2, color_n3]

fig, ax = plt.subplots(figsize=(18, 9))

for i, archivo in enumerate(sorted(carpeta.glob("*.txt"))):
    cols = leer_columnas(archivo)        # <-- TU función de carga
    if cols is None:
        continue
    cols = np.asarray(cols)
    if cols.ndim != 2 or cols.shape[0] <= max(v_col, i_col):
        continue

    V = np.asarray(cols[v_col], dtype=float)
    I = np.asarray(cols[i_col], dtype=float)

    # limpieza
    m = np.isfinite(V) & np.isfinite(I)
    V, I = V[m], I[m]
    if V.size == 0: 
        continue

    # parámetros adaptativos de picos
    rango = np.ptp(I)
    prominence = max(0.1, 0.05 * rango)
    distance   = max(5, len(I)//50)

    idx_max, _ = find_peaks(I,  distance=distance, prominence=prominence)
    idx_min, _ = find_peaks(-I, distance=distance, prominence=prominence)

    resultados2[archivo.stem] = {
        "V": V, "I": I,
        "idx_max": idx_max, "idx_min": idx_min
    }

    color = colores[i % len(colores)]
    ax.plot(V, I, marker="o", markersize=3, color=color, linewidth=0.9, label=archivo.stem)


    if idx_max.size:
        ax.plot(V[idx_max], I[idx_max], "x", color="black", markersize=6)
    if idx_min.size:
        ax.plot(V[idx_min], I[idx_min], "v", color="black", markersize=6)

ax.set_xlabel("Voltaje U1 (V)", fontsize=40, labelpad=12)
ax.set_ylabel(LABEL_Y, fontsize=40, labelpad=12)
ax.set_title("Voltaje vs Corriente - 180°", fontsize=40, pad=14)
ax.tick_params(axis="both", labelsize=35)   # <<< aumenta el tamaño de los números en los ejes
ax.grid(True)
plt.tight_layout()
plt.show()

# %%
#TABLA DE REGISTRO Y VARIACIÓN
Ea_ref_eV = 4.67   # eV

filas = []
resumen = []

for name, d in resultados2.items():
    V, I, idx_min = d["V"], d["I"], d["idx_min"]
    if idx_min.size < 2:
        continue

    # tabla detallada por archivo
    Vmins = V[idx_min]
    Imins = I[idx_min]
    dV = np.diff(Vmins)                      # separación entre mínimos consecutivos
    Ea_est = dV                              # (en eV ~ ΔV cuando la corrección es pequeña)
    err_abs = np.abs(Ea_est - Ea_ref_eV)
    err_rel = 100 * err_abs / Ea_ref_eV

    for k in range(len(dV)):
        filas.append({
            "archivo": name,
            "min_k": k, "V_min_k (V)": Vmins[k],
            "min_k+1": k+1, "V_min_k+1 (V)": Vmins[k+1],
            "ΔV (V)": dV[k],
            "E_a,est (eV)": Ea_est[k],
            "|E_a,est - 4.67| (eV)": err_abs[k],
            "error (%)": err_rel[k],
            "I_min_k (nA)": Imins[k],
            "I_min_k+1 (nA)": Imins[k+1],
        })

    # resumen por archivo (promedio)
    resumen.append({
        "archivo": name,
        "n_deltas": len(dV),
        "ΔV̄ (V)": np.mean(dV),
        "σ_ΔV (V)": np.std(dV, ddof=1) if len(dV) > 1 else np.nan,
        "E_a,est,mean (eV)": np.mean(Ea_est),
        "error_abs_mean (eV)": np.abs(np.mean(Ea_est) - Ea_ref_eV),
        "error_rel_mean (%)": 100*np.abs(np.mean(Ea_est) - Ea_ref_eV)/Ea_ref_eV
    })

#df_detalle = pd.DataFrame(filas)
df_resumen = pd.DataFrame(resumen).sort_values("archivo")

#print("► Tabla de mínimos consecutivos y estimación por ΔV (detalle):")
#display(df_detalle)

print("\n► Resumen por archivo (promedio y dispersión) para una temperatura de 180°:")
display(df_resumen)
# Out:
# ► Resumen por archivo (promedio y dispersión) para una temperatura de 180°:
#                                        archivo  n_deltas  ΔV̄ (V)  σ_ΔV (V)  \
# 0  20250918_Franck-Hertz_Actividad1_Toma1(180)         4   5.0225  0.112657
# 1  20250918_Franck-Hertz_Actividad1_Toma2(180)         4   4.9750  0.182665
# 2  20250918_Franck-Hertz_Actividad1_Toma3(180)         5   5.0100  0.120208
#
#    E_a,est,mean (eV)  error_abs_mean (eV)  error_rel_mean (%)
# 0             5.0225               0.3525            7.548180
# 1             4.9750               0.3050            6.531049
# 2             5.0100               0.3400            7.280514

# %%
# Carpetas
carpeta = Path("Data/Act1/180°")

# Resultados
resultados = {}
todos_diffs = []
todos_num = []

for archivo_ajuste in sorted(carpeta.glob("*AjusteMinimosyMaximos*.txt")):
    datos = []
    with open(archivo_ajuste, "r", encoding="utf-8") as f:
        for line in f:
            if line.startswith("mínimo"):
                parts = line.strip().split()
                if len(parts) >= 3:
                    voltaje = float(parts[1].replace(",", "."))
                    datos.append(voltaje)

    if not datos:
        continue

    diferencias = np.diff(datos)
    num_min = np.arange(1, len(diferencias) + 1)

    resultados[archivo_ajuste.stem] = (num_min, diferencias)

    # Guardar en arrays globales
    todos_diffs.extend(diferencias)
    todos_num.extend(num_min)

# Convertir a numpy arrays
todos_diffs = np.array(todos_diffs)
todos_num = np.array(todos_num)

# --- Ajuste lineal ---
coef = np.polyfit(todos_diffs, todos_num, 1)   # n = a*ΔV + b
a, b = coef
print(f"Ajuste lineal: n = {a:.3f} * ΔV + {b:.3f}")

# Puntos para la recta ajustada
x_fit = np.linspace(min(todos_diffs), max(todos_diffs), 200)
y_fit = a * x_fit + b

# --- Graficar ---
colores = ["#D6259B", "#51D63F", "#2580D6"]
fig, ax = plt.subplots(figsize=(12, 6))

for i, (nombre, (num_min, diffs)) in enumerate(resultados.items()):
    ax.scatter(diffs, num_min, color=colores[i % len(colores)], label=f"Toma {i+1}")

# Recta ajustada
ax.plot(x_fit, y_fit, "k--", linewidth=2, label=f"Ajuste: n = {a:.2f}·ΔV + {b:.2f}")
ax.set_title("Numero mínimo contra ΔV 180°", fontsize=40, pad=14)
ax.set_xlabel("ΔV entre mínimos (V)")
ax.set_ylabel("Número de mínimo")
ax.set_yticks(range(1, max(todos_num)+1))
ax.grid(True)
ax.legend(ncol=2, fontsize=9)
plt.show()
# Out:
# Ajuste lineal: n = 11.853 * ΔV + -55.564

# %%
# Carpetas
carpeta = Path("Data/Act1/180°")

# Resultados
resultados = {}
todos_diffs = []
todos_num = []

for archivo_ajuste in sorted(carpeta.glob("*AjusteMinimosyMaximos*.txt")):
    datos = []
    with open(archivo_ajuste, "r", encoding="utf-8") as f:
        for line in f:
            if line.startswith("mínimo"):
                parts = line.strip().split()
                if len(parts) >= 3:
                    voltaje = float(parts[1].replace(",", "."))
                    datos.append(voltaje)

    if not datos:
        continue

    diferencias = np.diff(datos)
    num_min = np.arange(1, len(diferencias) + 1)

    resultados[archivo_ajuste.stem] = (num_min, diferencias)

    # Guardar en arrays globales
    todos_diffs.extend(diferencias)
    todos_num.extend(num_min)

# Convertir a numpy arrays
todos_diffs = np.array(todos_diffs)
todos_num = np.array(todos_num)

# --- Ajuste lineal ---
coef = np.polyfit(todos_diffs, todos_num, 1)   # n = a*ΔV + b
a, b = coef
print(f"Ajuste lineal: n = {a:.3f} * ΔV + {b:.3f}")

# Puntos para la recta ajustada
x_fit = np.linspace(min(todos_diffs), max(todos_diffs), 200)
y_fit = a * x_fit + b

# --- Graficar ---
colores = ["#D6259B", "#51D63F", "#2580D6"]
fig, ax = plt.subplots(figsize=(12, 6))

for i, (nombre, (num_min, diffs)) in enumerate(resultados.items()):
    ax.scatter(diffs, num_min, color=colores[i % len(colores)], label=f"Toma {i+1}")

# Recta ajustada
ax.plot(x_fit, y_fit, "k--", linewidth=2, label=f"Ajuste: n = {a:.2f}·ΔV + {b:.2f}")

ax.set_xlabel("ΔV entre mínimos (V)")
ax.set_ylabel("Número de mínimo")
ax.set_yticks(range(1, max(todos_num)+1))
ax.grid(True)
ax.legend(ncol=2, fontsize=9)
plt.show()
# Out:
# Ajuste lineal: n = 11.853 * ΔV + -55.564

# %%
## GRÁFICAS PARA 185° ###
carpeta = Path("Data/Act1/185°")
v_col, i_col = 0, 1                      # índices: voltaje y corriente en lo que devuelva leer_columnas()
LABEL_Y = "Corriente (nA)"               # cambia si tu unidad no es nA

# Estructura para reutilizar en celdas siguientes
resultados3 = {}
color_n1 = "#D6259B"   # rosa fuerte
color_n2 = "#51D63F"   # verde
color_n3 = "#2580D6"   # azul
colores = [color_n1, color_n2, color_n3]

fig, ax = plt.subplots(figsize=(18, 9))

for i, archivo in enumerate(sorted(carpeta.glob("*.txt"))):
    cols = leer_columnas(archivo)        # <-- TU función de carga
    if cols is None:
        continue
    cols = np.asarray(cols)
    if cols.ndim != 2 or cols.shape[0] <= max(v_col, i_col):
        continue

    V = np.asarray(cols[v_col], dtype=float)
    I = np.asarray(cols[i_col], dtype=float)

    # limpieza
    m = np.isfinite(V) & np.isfinite(I)
    V, I = V[m], I[m]
    if V.size == 0: 
        continue

    # parámetros adaptativos de picos
    rango = np.ptp(I)
    prominence = max(0.1, 0.05 * rango)
    distance   = max(5, len(I)//50)

    idx_max, _ = find_peaks(I,  distance=distance, prominence=prominence)
    idx_min, _ = find_peaks(-I, distance=distance, prominence=prominence)

    resultados3[archivo.stem] = {
        "V": V, "I": I,
        "idx_max": idx_max, "idx_min": idx_min
    }

    color = colores[i % len(colores)]
    ax.plot(V, I, marker="o", markersize=3, color=color, linewidth=0.9, label=archivo.stem)


    if idx_max.size:
        ax.plot(V[idx_max], I[idx_max], "x", color="black", markersize=6)
    if idx_min.size:
        ax.plot(V[idx_min], I[idx_min], "v", color="black", markersize=6)

ax.set_xlabel("Voltaje U1 (V)", fontsize=40, labelpad=12)
ax.set_ylabel(LABEL_Y, fontsize=40, labelpad=12)
ax.set_title("Voltaje vs Corriente - 185°", fontsize=40, pad=14)
ax.tick_params(axis="both", labelsize=35)   # <<< aumenta el tamaño de los números en los ejes
ax.grid(True)
plt.tight_layout()
plt.show()

# %%
#TABLA DE REGISTRO Y VARIACIÓN
Ea_ref_eV = 4.67   # eV

filas = []
resumen = []

for name, d in resultados3.items():
    V, I, idx_min = d["V"], d["I"], d["idx_min"]
    if idx_min.size < 2:
        continue

    # tabla detallada por archivo
    Vmins = V[idx_min]
    Imins = I[idx_min]
    dV = np.diff(Vmins)                      # separación entre mínimos consecutivos
    Ea_est = dV                              # (en eV ~ ΔV cuando la corrección es pequeña)
    err_abs = np.abs(Ea_est - Ea_ref_eV)
    err_rel = 100 * err_abs / Ea_ref_eV

    for k in range(len(dV)):
        filas.append({
            "archivo": name,
            "min_k": k, "V_min_k (V)": Vmins[k],
            "min_k+1": k+1, "V_min_k+1 (V)": Vmins[k+1],
            "ΔV (V)": dV[k],
            "E_a,est (eV)": Ea_est[k],
            "|E_a,est - 4.67| (eV)": err_abs[k],
            "error (%)": err_rel[k],
            "I_min_k (nA)": Imins[k],
            "I_min_k+1 (nA)": Imins[k+1],
        })

    # resumen por archivo (promedio)
    resumen.append({
        "archivo": name,
        "n_deltas": len(dV),
        "ΔV̄ (V)": np.mean(dV),
        "σ_ΔV (V)": np.std(dV, ddof=1) if len(dV) > 1 else np.nan,
        "E_a,est,mean (eV)": np.mean(Ea_est),
        "error_abs_mean (eV)": np.abs(np.mean(Ea_est) - Ea_ref_eV),
        "error_rel_mean (%)": 100*np.abs(np.mean(Ea_est) - Ea_ref_eV)/Ea_ref_eV
    })

#df_detalle = pd.DataFrame(filas)
df_resumen = pd.DataFrame(resumen).sort_values("archivo")

#print("► Tabla de mínimos consecutivos y estimación por ΔV (detalle):")
#display(df_detalle)

print("\n► Resumen por archivo (promedio y dispersión) para una temperatura de 185°:")
display(df_resumen)
# Out:
# ► Resumen por archivo (promedio y dispersión) para una temperatura de 185°:
#                                        archivo  n_deltas   ΔV̄ (V)  σ_ΔV (V)  \
# 0  20250918_Franck-Hertz_Actividad1_Toma1(185)         5  4.968000  0.128919
# 1  20250918_Franck-Hertz_Actividad1_Toma2(185)         6  4.978333  0.136589
# 2  20250918_Franck-Hertz_Actividad1_Toma3(185)         6  4.948333  0.146208
#
#    E_a,est,mean (eV)  error_abs_mean (eV)  error_rel_mean (%)
# 0           4.968000             0.298000            6.381156
# 1           4.978333             0.308333            6.602427
# 2           4.948333             0.278333            5.960029

# %%
# Carpetas
carpeta = Path("Data/Act1/185°")

# Resultados
todos_diffs = []
todos_num = []

for archivo_ajuste in sorted(carpeta.glob("*AjusteMinimosyMaximos*.txt")):
    datos = []
    with open(archivo_ajuste, "r", encoding="utf-8") as f:
        for line in f:
            if line.startswith("mínimo"):
                parts = line.strip().split()
                if len(parts) >= 3:
                    voltaje = float(parts[1].replace(",", "."))
                    datos.append(voltaje)

    if not datos:
        continue

    diferencias = np.diff(datos)
    num_min = np.arange(1, len(diferencias) + 1)

    todos_diffs.extend(diferencias)
    todos_num.extend(num_min)

# Convertir a arrays
todos_diffs = np.array(todos_diffs)
todos_num = np.array(todos_num)

# --- Detección de outliers con IQR ---
Q1, Q3 = np.percentile(todos_diffs, [25, 75])
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

mask = (todos_diffs >= lower_bound) & (todos_diffs <= upper_bound)
diffs_filtrados = todos_diffs[mask]
num_filtrados = todos_num[mask]

print(f"Valores descartados (outliers): {np.sum(~mask)}")
print(f"Rango aceptado: {lower_bound:.2f} V – {upper_bound:.2f} V")

# --- Ajuste lineal sin outliers ---
coef = np.polyfit(diffs_filtrados, num_filtrados, 1)
a, b = coef
print(f"Ajuste filtrado: n = {a:.3f} * ΔV + {b:.3f}")

# Puntos de la recta ajustada
x_fit = np.linspace(min(diffs_filtrados), max(diffs_filtrados), 200)
y_fit = a * x_fit + b

# --- Graficar ---
fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(todos_diffs, todos_num, color="gray", alpha=0.4, label="Datos originales")
ax.scatter(diffs_filtrados, num_filtrados, color="blue", label="Datos filtrados")
ax.plot(x_fit, y_fit, "r--", linewidth=2, label=f"Ajuste: n = {a:.2f}·ΔV + {b:.2f}")
ax.set_title("Numero mínimo contra ΔV 185°", fontsize=40, pad=14)
ax.set_xlabel("ΔV entre mínimos (V)")
ax.set_ylabel("Número de mínimo")
ax.set_yticks(range(1, max(todos_num)+1))
ax.grid(True)
ax.set_xlim(4.5,5.2)
ax.legend()
plt.show()
# Out:
# Valores descartados (outliers): 1
# Rango aceptado: 4.42 V – 5.47 V
# Ajuste filtrado: n = 10.275 * ΔV + -46.359

# %% [markdown]
# Al centrar el pico en el origen y disminuir la temperatura del tubo (apagando la estufa y evitando bajar de 160 °C), se observó que la amplitud de los máximos de corriente disminuye progresivamente y los picos se vuelven menos definidos y más anchos. Esto se explica porque la presión de vapor del mercurio baja con la temperatura, reduciendo la densidad atómica y por tanto la probabilidad de colisiones inelásticas entre electrones y átomos necesarias para producir los picos. En casos de temperatura muy baja algunos picos desaparecen por completo. Se observó además un ligero desplazamiento de las posiciones en voltaje, consistente con un aumento de la longitud libre media de los electrones a menor densidad atómica. Se midieron las posiciones de los máximos y se calculó la separación promedio $$\bar{\Delta V}$$ se estimó la energía de excitación experimental como $$E \approx \bar{\Delta V} \; \text{eV}$$ la cual puede compararse con el valor teórico.

# %% [markdown]
# ---
#
# 2. Para valores de UH y U2 constantes registre la corriente IA y el voltaje U1 para diferentes temperaturas en el intervalo 165◦C-185◦C.
# 3. Con los datos para cada temperatura calcule la distancia entre m´ınimos y comp´arela con el valor esperado de 4,67eV . ¿ C´omo puede explicar las discrepancias.

# %%
#TEMPERATURA VARIANTE
carpeta = Path("Data/Act2/Temperatura Variante")  # ← sin símbolo °
v_col, i_col = 0, 1
LABEL_Y = "Corriente (nA)"

resultadoso = {}
color_n1 = "#D6259B"   # rosa fuerte
color_n2 = "#51D63F"   # verde
color_n3 = "#2580D6"   # azul
colores = [color_n1, color_n2, color_n3]

fig, ax = plt.subplots(figsize=(18, 9))

for i, archivo in enumerate(sorted(carpeta.glob("*.txt"))):
    cols = leer_columnas(archivo)
    if cols is None:
        continue
    cols = np.asarray(cols)
    if cols.ndim != 2 or cols.shape[0] <= max(v_col, i_col):
        continue

    V = np.asarray(cols[v_col][:1600], dtype=float)
    I = np.asarray(cols[i_col][:1600], dtype=float)

    m = np.isfinite(V) & np.isfinite(I)
    V, I = V[m], I[m]
    if V.size == 0:
        continue

    # picos (parámetros adaptativos)
    rango = np.ptp(I)
    prominence = max(0.1, 0.05 * rango)
    distance   = max(5, len(I)//50)

    idx_max, _ = find_peaks(I,  distance=distance, prominence=prominence)
    idx_min, _ = find_peaks(-I, distance=distance, prominence=prominence)

    resultadoso[archivo.stem] = {
        "V": V, "I": I, "idx_max": idx_max, "idx_min": idx_min
    }

    color = colores[i % len(colores)]

    ax.plot(V, I, marker="o", markersize=3, color=color, linewidth=0.9)

    # picos en negro
    if idx_max.size:
        ax.plot(V[idx_max], I[idx_max], "x", color="black", markersize=6)
    if idx_min.size:
        ax.plot(V[idx_min], I[idx_min], "v", color="black", markersize=6)

ax.set_xlabel("Voltaje U1 (V)", fontsize=40, labelpad=12)
ax.set_ylabel(LABEL_Y, fontsize=40, labelpad=12)
ax.set_title("Voltaje vs Corriente Temperatura Variable", fontsize=40, pad=14) 
ax.legend(fontsize=20)
ax.tick_params(axis="both", labelsize=35)   # <<< aumenta el tamaño de los números en los ejes
ax.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23816\2678928897.py:55: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=20)

# %%
Ea_ref_eV = 4.67  # eV (Hg)

# ===== Construcción de tablas =====
filas = []
for name, d in resultadoso.items():  # <-- usa tu diccionario aquí
    V = d["V"]; I = d["I"]; idx_min = d["idx_min"]
    if isinstance(idx_min, list):  # por si viniera como lista
        idx_min = np.asarray(idx_min, dtype=int)
    if idx_min.size < 2:
        continue

    Vmins = V[idx_min]
    Imins = I[idx_min]
    dV = np.diff(Vmins)                 # separación entre mínimos consecutivos
    Ea_est = dV                         # ≈ ΔV (si la corrección es pequeña)
    err_abs = np.abs(Ea_est - Ea_ref_eV)
    err_rel = 100 * err_abs / Ea_ref_eV

    for k, dv in enumerate(dV):
        filas.append({
            "archivo": name,
            "min_k": k,
            "V_min_k (V)": Vmins[k],
            "V_min_k+1 (V)": Vmins[k+1],
            "I_min_k (nA)": Imins[k],
            "I_min_k+1 (nA)": Imins[k+1],
            "ΔV (V)": dv,
            "E_a,est (eV)": Ea_est[k],
            "|E_a,est - 4.67| (eV)": err_abs[k],
            "error (%)": err_rel[k],
        })

# DataFrame detalle
if len(filas) == 0:
    print("No hay pares de mínimos suficientes para construir la tabla.")
else:
    df_detalle = (
        pd.DataFrame(filas)
        .sort_values(["archivo", "min_k"])
        .reset_index(drop=True)
    )

    # Resumen por archivo
    agg = (
        df_detalle.groupby("archivo")["ΔV (V)"]
        .agg(n_deltas="count", mean="mean", std=lambda x: x.std(ddof=1))
        .rename(columns={"mean": "ΔV̄ (V)", "std": "σ_ΔV (V)"})
    )
    df_resumen = agg.copy()
    df_resumen["E_a,est,mean (eV)"] = df_resumen["ΔV̄ (V)"]
    df_resumen["error_abs_mean (eV)"] = np.abs(df_resumen["E_a,est,mean (eV)"] - Ea_ref_eV)
    df_resumen["error_rel_mean (%)"] = 100 * df_resumen["error_abs_mean (eV)"] / Ea_ref_eV
    df_resumen = df_resumen.reset_index()

    # Redondeo y visualización
    cols_round_det = ["V_min_k (V)", "V_min_k+1 (V)", "I_min_k (nA)", "I_min_k+1 (nA)",
                      "ΔV (V)", "E_a,est (eV)", "|E_a,est - 4.67| (eV)", "error (%)"]
    cols_round_res = ["ΔV̄ (V)", "σ_ΔV (V)", "E_a,est,mean (eV)", "error_abs_mean (eV)", "error_rel_mean (%)"]

    df_detalle_show = df_detalle.copy()
    df_detalle_show[cols_round_det] = df_detalle_show[cols_round_det].round(3)

    df_resumen_show = df_resumen.copy()
    df_resumen_show[cols_round_res] = df_resumen_show[cols_round_res].round(3)

    print("► Tabla de mínimos consecutivos y estimación por ΔV (detalle):")
    display(df_detalle_show)

    print("\n► Resumen por archivo (promedio y dispersión) para diferentes temperaturas:")
# Out:
# ► Tabla de mínimos consecutivos y estimación por ΔV (detalle):
#                                               archivo  min_k  V_min_k (V)  \
# 0       20250918_Franck-Hertz_Actividad2_Toma1 (165°)      0        18.97
# 1       20250918_Franck-Hertz_Actividad2_Toma1 (165°)      1        23.85
# 2       20250918_Franck-Hertz_Actividad2_Toma1 (165°)      2        28.84
# 3   20250918_Franck-Hertz_Actividad2_Toma1 (165°) ...      0        19.02
# 4   20250918_Franck-Hertz_Actividad2_Toma1 (165°) ...      1        23.93
# 5   20250918_Franck-Hertz_Actividad2_Toma1 (165°) ...      2        28.98
# 6       20250918_Franck-Hertz_Actividad2_Toma2 (170°)      0        18.87
# 7       20250918_Franck-Hertz_Actividad2_Toma2 (170°)      1        23.73
# 8       20250918_Franck-Hertz_Actividad2_Toma2 (170°)      2        28.66
# 9   20250918_Franck-Hertz_Actividad2_Toma2 (170°) ...      0        19.07
# 10  20250918_Franck-Hertz_Actividad2_Toma2 (170°) ...      1        23.78
# ...

# %% [markdown]
# 4. Concentr´andose en valores menores registre d´onde ocurre el primer m´ınimo. ¿Por qu´e no sucede en 4,67eV ? ¿Qu´e podr´ıa calcular sabiendo la posici´on del primer m´ınimo? (Ayuda: tenga en cuenta el voltaje de retardo U2.)

# %%
Ea_ref_eV = 4.67  # eV (Hg)

# ===== Detectar mínimos automáticamente =====
minimos = {}
for name, d in resultados.items():   # d = (V, I)
    V, I = d
    # detectar picos en -I (equivalente a mínimos en I)
    idx_min, _ = find_peaks(-I, distance=2)  # 'distance' evita mínimos demasiado cercanos
    minimos[name] = idx_min

# ===== Construir tabla con primer mínimo =====
filas_first = []
for name, d in resultados.items():
    V, I = d
    idx_min = minimos[name]

    if idx_min is None or len(idx_min) < 1:
        continue

    # Primer mínimo
    Vmin1 = V[idx_min[0]]
    Imin1 = I[idx_min[0]]

    filas_first.append({
        "archivo": name,
        "V_min1 (V)": Vmin1,
        "I_min1 (nA)": Imin1,
    })

# Pasar a DataFrame
df_first = pd.DataFrame(filas_first).sort_values("archivo").reset_index(drop=True)

# === Comparar con archivo U2 si existe ===
if "U2" in df_first["archivo"].values:
    U2_val = df_first.loc[df_first["archivo"] == "U2", "V_min1 (V)"].values[0]
    df_first["U2 (V)"] = U2_val
    df_first["E_a_corr (eV)"] = df_first["V_min1 (V)"] - U2_val
    df_first["err_abs (eV)"] = np.abs(df_first["E_a_corr (eV)"] - Ea_ref_eV)
    df_first["err_rel (%)"] = 100 * df_first["err_abs (eV)"] / Ea_ref_eV

# Redondear columnas numéricas
cols_round = ["V_min1 (V)", "I_min1 (nA)", "U2 (V)", "E_a_corr (eV)", "err_abs (eV)", "err_rel (%)"]
df_first_show = df_first.copy()
for c in cols_round:
    if c in df_first_show.columns:
        df_first_show[c] = df_first_show[c].round(3)

print("► Primer mínimo y estimación corregida usando U2:")
display(df_first_show)
# Out:
# ► Primer mínimo y estimación corregida usando U2:
#                                              archivo  V_min1 (V)  I_min1 (nA)
# 0  20250918_Franck-Hertz_AjusteMinimosyMaximos_17...           3         4.86
# 1  20250918_Franck-Hertz_AjusteMinimosyMaximos_17...           2         4.76

# %% [markdown]
# En el experimento se observaron los primeros mínimos alrededor de 4.74, 4.66 y 5.06 V, valores que no coinciden exactamente con la energía de excitación esperada de 4.67 eV. Esto ocurre porque la posición del primer mínimo está desplazada por el voltaje de retardo 𝑈2, además de otros factores experimentales como los potenciales de contacto, el ensanchamiento de la distribución de energías y posibles errores de calibración en la medición.

# %% [markdown]
# ---
# 5.Para un valor de temperatura fijo cambie el valor de U2 (entre 1V y 2V) y registre los valores medidos de IA en funci´on de U1. Haga una sola gr´afica con sus resultados.

# %%
# TEMPERATURA CONSTANTE , U2 OSCILANDO
# Carpeta donde están tus archivos
carpeta = Path("Data/Act2/Temperatura Constante")

# Guardar resultados de cada archivo
resultados = {}
color_n1 = "#D6259B"   # rosa fuerte
color_n2 = "#51D63F"   # verde
color_n3 = "#2580D6"   # azul
colores = [color_n1, color_n2, color_n3]

# Tomar solo los primeros 7 archivos ordenados
archivos = sorted(list(carpeta.glob("*.txt")))[10:13]
print(archivos)
Nmax = 300

fig, ax = plt.subplots(figsize=(18, 9))

for i, archivo in enumerate(archivos):
    # Usar la función ya existente
    voltajes, corrientes = leer_columnas(archivo)

    if len(voltajes) == 0:
        continue

    # Detectar máximos y mínimos
    indices_max, _ = find_peaks(corrientes, distance=5, prominence=0.1)
    indices_min, _ = find_peaks(-corrientes, distance=5, prominence=0.1)

    # Guardar datos
    resultados[archivo.stem] = {
        "voltajes": voltajes,
        "corrientes": corrientes,
        "indices_max": indices_max,
        "indices_min": indices_min,
    }

    # Graficar
    labels = ["1V", "1.5V", "2V"]
    ax.plot(voltajes, corrientes, marker="o", markersize=3, color=colores[i],
            linewidth=0.8, label=labels[i])

    # Marcar máximos y mínimos
    ax.plot(voltajes[indices_max], corrientes[indices_max], "x", color="black", markersize=6)
    ax.plot(voltajes[indices_min], corrientes[indices_min], "v", color="black", markersize=6)

# Configuración de la gráfica
ax.set_xlabel("Voltaje U1 (V)", fontsize=40, labelpad=12)
ax.set_ylabel("Corriente (nA)", fontsize=40, labelpad=12)
ax.set_title("Voltaje vs Corriente - Temperatura Constante", fontsize=40, pad=14)
ax.tick_params(axis="both", labelsize=35)   # <<< aumenta el tamaño de los números en los ejes
ax.legend(fontsize= 35)
ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# [WindowsPath('Data/Act2/Temperatura Constante/20250918_Franck-Hertz_Actividad2_Toma6 (175°, U2 = 1V).txt'), WindowsPath('Data/Act2/Temperatura Constante/20250918_Franck-Hertz_Actividad2_Toma6 (180°, U2 = 1V) - copia.txt'), WindowsPath('Data/Act2/Temperatura Constante/20250918_Franck-Hertz_Actividad2_Toma7 (175°, U2 = 1.5V).txt')]

# %%
filas = []
for name, datos in resultados.items():
    V = datos["voltajes"]
    idx_min = datos["indices_min"]
    if len(idx_min) > 1:
        dV = np.diff(V[idx_min])
        filas.append({
            "archivo": name,
            "n_minimos": len(idx_min),
            "n_pares": len(dV),
            "ΔV̄ (V)": float(np.mean(dV)),
            "σ_ΔV (V)": float(np.std(dV, ddof=1)) if len(dV)>1 else np.nan
        })

df_resumen = pd.DataFrame(filas).sort_values("archivo")
display(df_resumen)
print(f"Archivos resumidos: {len(df_resumen)}")
# Out:
#                                              archivo  n_minimos  n_pares  \
# 0  20250918_Franck-Hertz_Actividad2_Toma6 (175°, ...          8        7
# 1  20250918_Franck-Hertz_Actividad2_Toma6 (180°, ...          9        8
# 2  20250918_Franck-Hertz_Actividad2_Toma7 (175°, ...          9        8
#
#     ΔV̄ (V)  σ_ΔV (V)
# 0  4.267143  1.835744
# 1  4.280000  1.652064
# 2  4.325000  1.706232
# Archivos resumidos: 3

# %% [markdown]
# ---
# 6. Para un valor de U2 y temperatura fijos. Cambie el valor de UH en el rango (6,3 ± 0,5)V . Explique c´omo cambia la curva IA vs U1 y sustente su respuesta en t´erminos de la emisi´on termoi´onica, la temperatura del c´atodo y la distribuci´on de Maxwell- Boltzmann de los electrones que de all´ı son emitidos. Use esta respuesta para sus-
# tentar el ancho en los valles y picos del patr´on observado.

# %%
# TEMPERATURA CONSTANTE , UH OSCILANDO

# TEMPERATURA CONSTANTE , U2 OSCILANDO
# Carpeta donde están tus archivos
carpeta = Path("Data/Act2/Temperatura Constante")

# Guardar resultados de cada archivo
resultados = {}

# Tomar solo los primeros 7 archivos ordenados
archivos = sorted(list(carpeta.glob("*.txt")))[0:10]
print(archivos)
Nmax = 300

fig, ax = plt.subplots(figsize=(18, 9))

for i, archivo in enumerate(archivos):
    # Usar la función ya existente
    voltajes, corrientes = leer_columnas(archivo)

    if len(voltajes) == 0:
        continue

    # --- Submuestreo ---
    if len(voltajes) > Nmax:
        idx = np.linspace(0, len(voltajes)-1, Nmax, dtype=int)
        voltajes = voltajes[idx]
        corrientes = corrientes[idx]

    # Detectar máximos y mínimos
    indices_max, _ = find_peaks(corrientes, distance=5, prominence=0.1)
    indices_min, _ = find_peaks(-corrientes, distance=5, prominence=0.1)

    # Guardar datos del archivo
    resultados[archivo.stem] = {
        "voltajes": voltajes,
        "corrientes": corrientes,
        "indices_max": indices_max,
        "indices_min": indices_min,
    }

    # Graficar la curva
    labels = ["5,9V", "6V", "6.1V","6.2V", "6.3V", "6.4V", "6.5V", "6.6V","6.7V", "6.8V"]
    ax.plot(voltajes, corrientes, markersize=3,
            linewidth=2.5, label=labels[i])

    # Marcar máximos y mínimos (en negro)
    ax.plot(voltajes[indices_max], corrientes[indices_max], "x", color="black", markersize=6)
    ax.plot(voltajes[indices_min], corrientes[indices_min], "v", color="black", markersize=6)

# Configuración de la gráfica
ax.set_xlabel("Voltaje U1 (V)", fontsize=40, labelpad=12)
ax.set_ylabel("Corriente (nA)", fontsize=40, labelpad=12)
ax.set_title("Voltaje vs Corriente - Temperatura Constante", fontsize=40, pad=14)
ax.tick_params(axis="both", labelsize=35)   # <<< aumenta el tamaño de los números en los ejes
#ax.legend(fontsize= 45)
ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# [WindowsPath('Data/Act2/Temperatura Constante/20250918_Franck-Hertz_Actividad2_Toma10(175°, UH = 5,9V).txt'), WindowsPath('Data/Act2/Temperatura Constante/20250918_Franck-Hertz_Actividad2_Toma11(175°, UH = 6V).txt'), WindowsPath('Data/Act2/Temperatura Constante/20250918_Franck-Hertz_Actividad2_Toma12(175°, UH = 6,1V).txt'), WindowsPath('Data/Act2/Temperatura Constante/20250918_Franck-Hertz_Actividad2_Toma13(175°, UH = 6,2V).txt'), WindowsPath('Data/Act2/Temperatura Constante/20250918_Franck-Hertz_Actividad2_Toma14(175°, UH = 6,3V).txt'), WindowsPath('Data/Act2/Temperatura Constante/20250918_Franck-Hertz_Actividad2_Toma15(175°, UH = 6,4V).txt'), WindowsPath('Data/Act2/Temperatura Constante/20250918_Franck-Hertz_Actividad2_Toma156(175°, UH = 6,5V).txt'), WindowsPath('Data/Act2/Temperatura Constante/20250918_Franck-Hertz_Actividad2_Toma17(175°, UH = 6,6V).txt'), WindowsPath('Data/Act2/Temperatura Constante/20250918_Franck-Hertz_Actividad2_Toma18(175°, UH = 6,7V).txt'), WindowsPath('Data
# ...

# %%
filas = []
for name, datos in resultados.items():
    V = datos["voltajes"]
    idx_min = datos["indices_min"]
    if len(idx_min) > 1:
        dV = np.diff(V[idx_min])
        filas.append({
            "archivo": name,
            "n_minimos": len(idx_min),
            "n_pares": len(dV),
            "ΔV̄ (V)": float(np.mean(dV)),
            "σ_ΔV (V)": float(np.std(dV, ddof=1)) if len(dV)>1 else np.nan
        })

df_resumen = pd.DataFrame(filas).sort_values("archivo")
display(df_resumen)
print(f"Archivos resumidos: {len(df_resumen)}")
# Out:
#                                              archivo  n_minimos  n_pares  \
# 0  20250918_Franck-Hertz_Actividad2_Toma10(175°, ...          7        6
# 1  20250918_Franck-Hertz_Actividad2_Toma11(175°, ...          7        6
# 2  20250918_Franck-Hertz_Actividad2_Toma12(175°, ...          7        6
# 3  20250918_Franck-Hertz_Actividad2_Toma13(175°, ...          7        6
# 4  20250918_Franck-Hertz_Actividad2_Toma14(175°, ...          7        6
# 5  20250918_Franck-Hertz_Actividad2_Toma15(175°, ...          7        6
# 6  20250918_Franck-Hertz_Actividad2_Toma156(175°,...          7        6
# 7  20250918_Franck-Hertz_Actividad2_Toma17(175°, ...          7        6
# 8  20250918_Franck-Hertz_Actividad2_Toma18(175°, ...          7        6
# 9  20250918_Franck-Hertz_Actividad2_Toma19(175°, ...          7        6
#
#     ΔV̄ (V)  σ_ΔV (V)
# 0  4.945000  0.169204
# 1  4.945000  0.272525
# 2  4.913333  0.206462
# 3  4.945000  0.162327
# 4  4.981667  0.196308
# 5  4.945000  0.205791
# ...

# %% [markdown]
# En la gráfica se observa la corriente I frente al voltaje U para distintas mediciones, con temperatura y
# U2 constantes, variando UH. Los picos y valles característicos del experimento de Franck-Hertz reflejan las excitaciones electrónicas del gas. Al aumentar UH, más electrones alcanzan la energía suficiente para superar colisiones inelásticas, aumentando la corriente general y ensanchando los picos y valles; al disminuir UH, la corriente disminuye y los picos y valles se hacen más estrechos y profundos. Esto se explica por la distribución de energías de los electrones emitidos por el cátodo según Maxwell-Boltzmann, que no es uniforme, lo que da a los picos un ancho finito en lugar de ser infinitamente delgados.

# %% [markdown]
# ---
# 7. Con las mediciones que ya ha realizado haga una gr´afica de distancia entre m´ınimos
# en funci´on del orden del m´ınimo. ¿Observa este comportamiento creciente lineal? (Las diferencias son relativamente peque˜nas as´ı que procure hacer las mediciones con la mayor precisi´on posible). Para cada temperatura obtenga una regresi´on lineal (entre distancia entre m´ınimos y orden del m´ınimo) y con el valor de la pendiente
# calcule el camino libre medio experimental con la ecuaci´on
# ¯`exp = L
# 2Ea
# d∆E(n)
# dn , (8)
# comparando sus resultados con los que obtuvo en el punto 2 del Ejercicio 3).
# Adicionalmente, con las regresiones que realiz´o, calcule el valor de Ea mediante la
# evaluaci´on de ∆E(0,5), compare su valor con el valor reportado de 4.67eV. Use un
# valor de L = 12cm.

# %%
# Carpetas
carpeta = Path("Data/Act2/Temperatura Constante")

# Resultados
todos_diffs = []
todos_num = []

for archivo_ajuste in sorted(carpeta.glob("*AjusteMinimosyMaximos*.txt")):
    datos = []
    with open(archivo_ajuste, "r", encoding="utf-8") as f:
        for line in f:
            if line.startswith("mínimo"):
                parts = line.strip().split()
                if len(parts) >= 3:
                    voltaje = float(parts[1].replace(",", "."))
                    datos.append(voltaje)

    if not datos:
        continue

    diferencias = np.diff(datos)
    num_min = np.arange(1, len(diferencias) + 1)

    todos_diffs.extend(diferencias)
    todos_num.extend(num_min)

# Convertir a arrays
todos_diffs = np.array(todos_diffs)
todos_num = np.array(todos_num)

# --- Detección de outliers con IQR ---
Q1, Q3 = np.percentile(todos_diffs, [25, 75])
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

mask = (todos_diffs >= lower_bound) & (todos_diffs <= upper_bound)
diffs_filtrados = todos_diffs[mask]
num_filtrados = todos_num[mask]

print(f"Valores descartados (outliers): {np.sum(~mask)}")
print(f"Rango aceptado: {lower_bound:.2f} V – {upper_bound:.2f} V")

# --- Ajuste lineal sin outliers ---
coef = np.polyfit(diffs_filtrados, num_filtrados, 1)
a, b = coef
print(f"Ajuste filtrado: n = {a:.3f} * ΔV + {b:.3f}")

# Puntos de la recta ajustada
x_fit = np.linspace(min(diffs_filtrados), max(diffs_filtrados), 200)
y_fit = a * x_fit + b

# --- Graficar ---
fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(todos_diffs, todos_num, color="gray", alpha=0.4, label="Datos originales")
ax.scatter(diffs_filtrados, num_filtrados, color="blue", label="Datos filtrados")
ax.plot(x_fit, y_fit, "r--", linewidth=2, label=f"Ajuste: n = {a:.2f}·ΔV + {b:.2f}")
ax.set_title("Numero mínimo contra ΔV Temperatura constante", fontsize=40, pad=14)
ax.set_xlabel("ΔV entre mínimos (V)")
ax.set_ylabel("Número de mínimo")
ax.set_yticks(range(1, max(todos_num)+1))
ax.grid(True)
ax.legend()
ax.set_xlim(4.5,5.5)
plt.show()
# Out:
# Valores descartados (outliers): 1
# Rango aceptado: 4.48 V – 5.49 V
# Ajuste filtrado: n = 8.875 * ΔV + -40.747

# %% [markdown]
# Se graficó la distancia entre mínimos $\Delta V$ en función del orden del mínimo $n$ y se ajustó una recta a los datos.
# Algebraicamente, los ajustes se escribieron como
#
# $$
# n = m\,\Delta V + b,
# $$
#
# de donde se obtiene
#
# $$
# \Delta V(n) = \frac{1}{m}n - \frac{b}{m},
# $$
#
# por lo que $\Delta V$ crece linealmente con $n$.
#
# Para cada temperatura se calculó la pendiente efectiva $\tfrac{d\Delta E}{dn} = \tfrac{1}{m}$ y el camino libre medio experimental mediante
#
# $$
# \bar{\ell}_{\rm exp} = \frac{L}{2E_a}\,\frac{d\Delta E}{dn},
# $$
#
# con $L = 12 \,\text{cm}$ y $E_a = 4.67 \,\text{eV}$.
# Los resultados obtenidos para la actividad 1 fueron:
#
# - **Curva A (175°):** $\bar{\ell}_{\rm exp} = 1.02\times10^{-3}\,\text{m}$,
#   $E_{a,\rm exp} = \Delta E(0.5) = 4.683 \,\text{eV}$.
#
# - **Curva B (180°):** $\bar{\ell}_{\rm exp} = 1.08\times10^{-3}\,\text{m}$,
#   $E_{a,\rm exp} = 4.730 \,\text{eV}$.
#
# - **Curva C(185°):** $\bar{\ell}_{\rm exp} = 1.25\times10^{-3}\,\text{m}$,
#   $E_{a,\rm exp} = 4.560 \,\text{eV}$.
#
#
#
# Los valores experimentales de $E_a$ difieren del valor reportado $4.67eV$ en menos del 3% en todos los casos, lo que indica buena concordancia.
#
# **Ajuste filtrado (175°–185°, rango 4.48–5.49 V):**
#   $\bar{\ell}_{\rm exp} = 1.45\times10^{-3}\,\text{m}$,
#   $E_{a,\rm exp} = 4.648 \,\text{eV}$.
#
# En este caso, el valor de \(E_a\) coincide con el reportado (\(4.67\,\text{eV}\)) con un error menor al 0.5%, confirmando la robustez del ajuste.
# No obstante, la longitud libre media resulta más elevada que en las curvas individuales (entre un 16% y 42% mayor), lo cual indica que el filtrado de valores extremos modifica la pendiente efectiva de la relación \(n\) vs. Delta V.

# %%
# Carpeta donde están tus archivos
carpeta = Path("Data/Act2/Temperatura Constante")

# Tomar solo los primeros 7 archivos ordenados
archivos = sorted(list(carpeta.glob("*.txt")))[:7]

# Número máximo de puntos por curva (submuestreo)
Nmax = 300

plt.figure(figsize=(10, 6))

for archivo in archivos:
    voltaje, corriente =leer_columnas(archivo)
    
    # --- Submuestreo ---
    if len(voltajes) > Nmax:
        idx = np.linspace(0, len(voltajes)-1, Nmax, dtype=int)
        voltajes = voltajes[idx]
        corrientes = corrientes[idx]

    # Detectar mínimos
    indices_min, _ = find_peaks(-corrientes, distance=5, prominence=0.1)

    if len(indices_min) > 1:
        dif_volt = np.diff(voltajes[indices_min])

        # Graficar ΔV vs número de mínimo para este archivo
        plt.plot(
            range(1, len(dif_volt)+1),
            dif_volt,
            "o-",
            label=archivo.stem
        )

# Configuración de la gráfica
plt.xlabel("Número de mínimo consecutivo", fontsize=16)
plt.ylabel("ΔV entre mínimos (V)", fontsize=16)
plt.title("ΔV entre mínimos consecutivos por archivo", fontsize=18)
plt.legend(loc="best", fontsize=9)
plt.grid(True)
plt.show()

# %% [markdown]
# A partir de la separación entre mínimos obtenida en las curvas de corriente contra voltaje, se determinó un valor promedio de ΔV≈5.02V, con una dispersión típica de ±0.15V. Este resultado se encuentra cercano, aunque sistemáticamente mayor, al valor esperado de 4.67eV correspondiente a la primera energía de excitación del mercurio. La discrepancia, de aproximadamente un 7–8%, puede atribuirse a diversos factores experimentales: la existencia de un potencial de contacto entre electrodos que introduce un desplazamiento adicional en la posición de los picos; la distribución inicial de energías de los electrones y el ensanchamiento asociado a la temperatura; la ocurrencia de colisiones múltiples en picos de orden superior; así como posibles errores instrumentales en la calibración del voltaje o en la identificación de los mínimos. En conjunto, estas limitaciones experimentales explican el ligero corrimiento respecto al valor teórico, manteniendo sin embargo la consistencia general del resultado con la predicción del modelo de Franck-Hertz.

# %% [markdown]
# ---
# ## Para considerar
#
# ### 1. Magnitud de los efectos en el experimento
#
# | Variable | Efecto en el experimento |
# |----------|--------------------------|
# | **Campo magnético terrestre o externos** | Desvían ligeramente la trayectoria de los electrones, introduciendo ruido o variaciones en las gráficas. |
# | **Condición de vacío en el tubo** | Si es deficiente, aparecen colisiones adicionales no deseadas que distorsionan o invalidan la medición. |
# | **No uniformidad del campo eléctrico** | Los electrones no ganan la misma energía → picos ensanchados y errores en la energía de excitación. |
# | **No uniformidad de la temperatura en la estufa** | Cambia la densidad de átomos de Hg → modifica el camino libre medio y la posición de colisiones. |
#
# ---
#
# ### 2. Estrategias para minimizar los efectos
#
# | Variable | Cómo minimizarlo |
# |----------|------------------|
# | **Campos magnéticos externos** | Orientar el tubo respecto al campo terrestre; usar blindaje de mu-metal; evitar equipos eléctricos cercanos. |
# | **Condición de vacío** | Utilizar tubos sellados de calidad; evitar fugas; mantener el sistema limpio y libre de contaminantes. |
# | **No uniformidad del campo eléctrico** | Verificar alineación de electrodos; usar fuentes de voltaje estables y de bajo ruido. |
# | **No uniformidad de la temperatura** | Usar estufa calibrada; esperar estabilización térmica antes de medir; trabajar en rango seguro (~180 °C). |
